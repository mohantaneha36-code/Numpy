# %% [markdown]
# Handling Missing values
# isnull()
# notnull()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 4   No                 Arjun      NaN        22.0  45.0     NaN
# 5  yes                 Bheem      NaN        34.0  45.0     NaN
# 6  yes               Hanuman      NaN        44.0  65.0    98.0
# 7  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 8  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.isnull()
# Out:
#     Data   Name  Roll no  percentage    age  Number
# 0  False  False    False       False  False   False
# 1  False  False    False       False  False   False
# 2  False  False    False        True  False   False
# 3  False  False    False       False  False    True
# 4  False  False     True       False  False    True
# 5  False  False     True       False  False    True
# 6  False  False     True       False  False   False
# 7   True  False    False       False   True   False
# 8  False  False    False       False   True   False

# %%
df.isnull().sum() # No. of Null valus in each column
# Out:
# Data          1
# Name          0
# Roll no       3
# percentage    1
# age           2
# Number        3
# dtype: int64

# %%
df.isnull().sum().sum() #Total null values
# Out:
# np.int64(10)

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 4   No                 Arjun      NaN        22.0  45.0     NaN
# 5  yes                 Bheem      NaN        34.0  45.0     NaN
# 6  yes               Hanuman      NaN        44.0  65.0    98.0
# 7  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 8  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.notnull() #Opposite of isnull()
# Out:
#     Data  Name  Roll no  percentage    age  Number
# 0   True  True     True        True   True    True
# 1   True  True     True        True   True    True
# 2   True  True     True       False   True    True
# 3   True  True     True        True   True   False
# 4   True  True    False        True   True   False
# 5   True  True    False        True   True   False
# 6   True  True    False        True   True    True
# 7  False  True     True        True  False    True
# 8   True  True     True        True  False    True

# %%
df.notnull().sum()
# Out:
# Data          8
# Name          9
# Roll no       6
# percentage    8
# age           7
# Number        6
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(44)

# %%
#Series
import numpy as np
sr = pd.Series([1,2,3,4,np.nan,6,np.nan])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# 6    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# np.int64(2)

# %%
sr.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
sr.notnull().sum()
# Out:
# np.int64(5)

# %%
df
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 4   No                 Arjun      NaN        22.0  45.0     NaN
# 5  yes                 Bheem      NaN        34.0  45.0     NaN
# 6  yes               Hanuman      NaN        44.0  65.0    98.0
# 7  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 8  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
#dropna() = it drops the rows or columns having NAN value and creates a new dataframe
df.dropna()
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0

# %%
df.dropna(axis = 1) #Drops the columns having null value
# Out:
#                    Name
# 0          Neha Mohanta
# 1  Dibya Lochan Mohanta
# 2  Jyotirmayee Mohanata
# 3                Laxman
# 4                 Arjun
# 5                 Bheem
# 6               Hanuman
# 7            Ashwathama
# 8             Rajashree

# %%
df.dropna(how = 'any')
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0

# %%
df.dropna(axis=1,how = 'any') #By default input of how is any and can choose all if all valus are null
# Out:
#                    Name
# 0          Neha Mohanta
# 1  Dibya Lochan Mohanta
# 2  Jyotirmayee Mohanata
# 3                Laxman
# 4                 Arjun
# 5                 Bheem
# 6               Hanuman
# 7            Ashwathama
# 8             Rajashree

# %%
df.dropna(how = 'all')
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 4   No                 Arjun      NaN        22.0  45.0     NaN
# 5  yes                 Bheem      NaN        34.0  45.0     NaN
# 6  yes               Hanuman      NaN        44.0  65.0    98.0
# 7  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 8  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 4  NaN                   NaN      NaN         NaN   NaN     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 6  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.dropna(how = 'all')#Drops the row or column i.e 4 if it's all values are null
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 6  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.dropna(thresh = 1) #prints if atlest one value is notnull
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 6  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.dropna(thresh = 2)
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 6  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.dropna(thresh = 5)
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 4  NaN                   NaN      NaN         NaN   NaN     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 6  NaN            Ashwathama     23.0        55.0   NaN    89.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.dropna(subset = ['Data'])#Drops the rows corresponding to the given column containing NAN
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0
# 7  yes             Rajashree     45.0        33.0   NaN    43.0

# %%
df.dropna(subset = ['age'])
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
# 2  yes  Jyotirmayee Mohanata     34.0         NaN  24.0    22.0
# 3  yes                Laxman     23.0        45.0  67.0     NaN
# 5  yes               Hanuman      NaN        44.0  65.0    98.0

# %%
df.dropna(inplace = True) #We have to call df here 'inplace' as it doesnot create a new data frame .it just modifies the existing data frame
df
# Out:
#   Data                  Name  Roll no  percentage   age  Number
# 0  yes          Neha Mohanta     49.0        85.0  20.0    39.0
# 1  yes  Dibya Lochan Mohanta     65.0        87.0  18.0    11.0
