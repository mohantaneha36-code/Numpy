# %% [markdown]
# ##How To Write CSV Files In Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv') #dataset
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11
# 1  Jyotirmayee Mohanata  34  90  24  22

# %%
type(df) #The csv file is in data frame format
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Neha Mohanta', '49', '85', '20', '0'], dtype='object')

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',nrows = 1)
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',nrows = 5)
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11
# 1  Jyotirmayee Mohanata  34  90  24  22

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',usecols = [0])
df
# Out:
#            Neha Mohanta
# 0  Dibya Lochan Mohanta
# 1  Jyotirmayee Mohanata

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',usecols = [0,1])
df
# Out:
#            Neha Mohanta  49
# 0  Dibya Lochan Mohanta  65
# 1  Jyotirmayee Mohanata  34

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',usecols = [1,2,3,4])
df
# Out:
#    49  85  20   0
# 0  65  87  18  11
# 1  34  90  24  22

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11
# 1  Jyotirmayee Mohanata  34  90  24  22

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',skiprows = 1)
df
# Out:
#    Dibya Lochan Mohanta  65  87  18  11
# 0  Jyotirmayee Mohanata  34  90  24  22

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',skiprows = 2)
df
# Out:
# Empty DataFrame
# Columns: [Jyotirmayee Mohanata, 34, 90, 24, 22]
# Index: []

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',skiprows = [0])
df
# Out:
#    Dibya Lochan Mohanta  65  87  18  11
# 0  Jyotirmayee Mohanata  34  90  24  22

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',skiprows = [2])
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',skiprows = [1,2,3,4])
df
# Out:
# Empty DataFrame
# Columns: [Neha Mohanta, 49, 85, 20, 0]
# Index: []

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11
# 1  Jyotirmayee Mohanata  34  90  24  22

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/New.csv',index_col = '20')
df
# Out:
#             Neha Mohanta  49  85   0
# 20
# 18  Dibya Lochan Mohanta  65  87  11
# 24  Jyotirmayee Mohanata  34  90  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',index_col = 1)
df
# Out:
#                           Name  Percentage  Age  Number
# Roll No
# 49                Neha Mohanta          85   20       0
# 65        Dibya Lochan Mohanta          87   18      11
# 34        Jyotirmayee Mohanata          90   24      22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#                       0         1           2    3       4
# 0                  Name  Roll No   Percentage  Age  Number
# 1          Neha Mohanta        49          85   20       0
# 2  Dibya Lochan Mohanta        65          87   18      11
# 3  Jyotirmayee Mohanata        34          90   24      22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',header = [1])
df
# Out:
#    Dibya Lochan Mohanta  65  87  18  11
# 0  Jyotirmayee Mohanata  34  90  24  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11
# 1  Jyotirmayee Mohanata  34  90  24  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',header = [1])
df
# Out:
#    Dibya Lochan Mohanta  65  87  18  11
# 0  Jyotirmayee Mohanata  34  90  24  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv')
df
# Out:
#            Neha Mohanta  49  85  20   0
# 0  Dibya Lochan Mohanta  65  87  18  11
# 1  Jyotirmayee Mohanata  34  90  24  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',header = None)
df
# Out:
#                       0   1   2   3   4
# 0          Neha Mohanta  49  85  20   0
# 1  Dibya Lochan Mohanta  65  87  18  11
# 2  Jyotirmayee Mohanata  34  90  24  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',header = None, prefix = 'Columns')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',header = None, prefix = 'Columns')
#       2 df
#
# TypeError: read_csv() got an unexpected keyword argument 'prefix'

# %%
df = df.add_prefix('Data')
df
# Out:
#   DataColColumnsColumns0  DataColColumnsColumns1  DataColColumnsColumns2  \
# 0           Neha Mohanta                      49                      85
# 1   Dibya Lochan Mohanta                      65                      87
# 2   Jyotirmayee Mohanata                      34                      90
#
#    DataColColumnsColumns3  DataColColumnsColumns4
# 0                      20                       0
# 1                      18                      11
# 2                      24                      22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',names = ['a','b','c','d','e'])
df
# Out:
#                       a   b   c   d   e
# 0          Neha Mohanta  49  85  20   0
# 1  Dibya Lochan Mohanta  65  87  18  11
# 2  Jyotirmayee Mohanata  34  90  24  22

# %%
df =  pd.read_csv('C:/Users/DELL/Downloads/New.csv',names = ['Name','Roll NO','Percentage','Age','Number'])
df
# Out:
#                    Name  Roll NO  Percentage  Age  Number
# 0          Neha Mohanta       49          85   20       0
# 1  Dibya Lochan Mohanta       65          87   18      11
# 2  Jyotirmayee Mohanata       34          90   24      22
