# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/DELL/Downloads/room.csv')
# Out:
#         neha
# 0      jyoti
# 1       lopa
# 2  jayashree
# 3     pragya

# %%
import os

# %%
print(os.getcwd())
# Out:
# d:\NumPy
