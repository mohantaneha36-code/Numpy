# %% [markdown]
# Random Sampling with Numpy

# %%
#To generate random data
import numpy as np

# %%
import random

# %%
np.random.random(1) #Gives a value in between 0 and 1 as a array
# Out:
# array([0.44805207])

# %%
np.random.random((3,3))
# Out:
# array([[0.75152898, 0.43962847, 0.38790542],
#        [0.87986406, 0.80749605, 0.66756898],
#        [0.86061609, 0.46172576, 0.16786728]])

# %%
#To get random integer value
np.random.randint(1,4) 
#Here 4 is exclusive
# Out:
# 1

# %%
np.random.randint(1,4,(4,4)) #Created a 2 D array
# Out:
# array([[3, 2, 3, 1],
#        [3, 2, 2, 3],
#        [2, 1, 3, 2],
#        [1, 1, 1, 1]], dtype=int32)

# %%
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[1, 2, 2, 2],
#         [1, 1, 3, 3],
#         [2, 2, 3, 2],
#         [1, 1, 3, 2]],
#
#        [[2, 2, 2, 3],
#         [2, 2, 2, 3],
#         [2, 1, 1, 2],
#         [1, 1, 2, 3]]], dtype=int32)

# %%
np.random.seed(10)
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[2, 2, 1, 1],
#         [2, 1, 2, 2],
#         [1, 2, 2, 3],
#         [1, 2, 1, 3]],
#
#        [[1, 3, 1, 1],
#         [1, 3, 1, 3],
#         [3, 2, 1, 1],
#         [3, 2, 3, 2]]], dtype=int32)

# %%
#To use the same random value i.e used before seed() is used
np.random.seed(10)
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[2, 2, 1, 1],
#         [2, 1, 2, 2],
#         [1, 2, 2, 3],
#         [1, 2, 1, 3]],
#
#        [[1, 3, 1, 1],
#         [1, 3, 1, 3],
#         [3, 2, 1, 1],
#         [3, 2, 3, 2]]], dtype=int32)

# %%
2 ** 32 -1
#This much type of random values can be generated
# Out:
# 4294967295

# %%
np.random.rand(3) # rand() can creat nd array
# Out:
# array([0.13145815, 0.41366737, 0.77872881])

# %%
np.random.randn(3,3) #randn() Gives both positive and negative random values
# Out:
# array([[-1.25424191,  0.33157855, -0.30860049],
#        [-0.15373549,  0.67893119, -1.91355421],
#        [-0.94245806, -1.74554298, -1.02094527]])

# %%
x = [1,2,3,4]
np.random.choice(x)
# Out:
# np.int64(1)

# %%
np.random.choice(x)
# Out:
# np.int64(3)

# %%
np.random.choice(x)
# Out:
# np.int64(1)

# %%
for i in range(20):
    print(np.random.choice(x))
# Out:
# 1
# 1
# 2
# 1
# 4
# 1
# 1
# 3
# 1
# 3
# 3
# 1
# 4
# 2
# 1
# 4
# 2
# 3
# 3
# 2

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
#Permutation
np.random.permutation(x)
# Out:
# array([1, 2, 4, 3])

# %%
np.random.permutation(x)
# Out:
# array([2, 4, 3, 1])

# %% [markdown]
# String Operations, Comparision and information

# %%
ch_name = "Indian AI Production"
str1 = " Learning Python  Numpy "
np.char.add(ch_name,str1)
# Out:
# np.str_('Indian AI Production Learning Python  Numpy ')

# %%
np.char.lower(ch_name)
# Out:
# array('indian ai production', dtype='<U20')

# %%
np.char.upper(str1)
# Out:
# array(' LEARNING PYTHON  NUMPY ', dtype='<U24')

# %%
np.char.center(str1, 60)
# Out:
# array('                   Learning Python  Numpy                   ',
#       dtype='<U60')

# %%
np.char.center(str1,60,fillchar = "*")
# Out:
# array('****************** Learning Python  Numpy ******************',
#       dtype='<U60')

# %%
np.char.split(ch_name)
# Out:
# array(list(['Indian', 'AI', 'Production']), dtype=object)

# %%
np.char.splitlines("hello\nIndian")
# Out:
# array(list(['hello', 'Indian']), dtype=object)

# %%
str4 = "dmy"
str5 = "dmy"

# %%
np.char.join([":","/"],[str4,str5])
# Out:
# array(['d:m:y', 'd/m/y'], dtype='<U5')

# %%
np.char.replace(ch_name,"AI","Artificial Intelligence")
# Out:
# array('Indian Artificial Intellige Production', dtype='<U38')

# %%
np.char.equal(str4,str5)
# Out:
# array(True)

# %%
np.char.count(ch_name,"a")
# Out:
# np.int64(1)

# %%
ch_name
# Out:
# 'Indian AI Production'

# %%
np.char.find(ch_name,"AI")
# Out:
# np.int64(7)
