# %% [markdown]
# Pandas fillna() = It filla the NaN values with given values(input)
# #Syntax   :    DataFrame.fillna()

# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/DELL/Downloads/New.csv')
